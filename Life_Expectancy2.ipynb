# %% [markdown]
# <a href="https://colab.research.google.com/github/RichardKameri/tydata/blob/main/Life_Expectancy2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# LOAD THE DATA

# %%
df=pd.read_csv('/content/Life Expectancy Data.csv')

# %%
print(df.head())
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %% [markdown]
# DATA CLEANING

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1649 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          1649 non-null   object
#  1   Year                             1649 non-null   int64
#  2   Status                           1649 non-null   object
#  3   Life expectancy                  1649 non-null   float64
#  4   Adult Mortality                  1649 non-null   float64
#  5   infant deaths                    1649 non-null   int64
#  6   Alcohol                          1649 non-null   float64
#  7   percentage expenditure           1649 non-null   float64
#  8   Hepatitis B                      1649 non-null   float64
#  9   Measles                          1649 non-null   int64
#  10   BMI                             1649 non-null   float64
#  11  under-five deaths                1649 non-null   int64
# ...

# %%
# convert columns to appropriate data type
df['Life expectancy ']=pd.to_numeric(df['Life expectancy '],errors='coerce')
df['Adult Mortality']=pd.to_numeric(df['Adult Mortality'],errors='coerce')

# %%
df['year']=pd.to_datetime(df['Year'],format='%Y')

# %% [markdown]
# Exploratory Data Analysis EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Set the style for Seaborn
sns.set(style="whitegrid")

# %% [markdown]
# Line plot of life expectancy over time for developed and developing countries

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=df,x='year',y='Life expectancy ',hue='Status')
plt.title('Life Expectancy Over Time for Developed and Developing Countries')
plt.xlabel('Year')
plt.ylabel('Life Expectancy')
plt.show()

# %% [markdown]
# BOX PLOT FOR LIFE EXPECTANCY

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df,x='Status',y='Life expectancy ')
plt.title('Box Plot of Life Expectancy for Developed and Developing Countries')
plt.xlabel('Status')
# Out:
# Text(0.5, 0, 'Status')

# %% [markdown]
# Scatter plot of GDP vs Life Expectancy for developed and developing countries

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=df,x='GDP',y='Life expectancy ',hue='Status')
plt.title('Scatter Plot of GDP vs Life Expectancy for Developed and Developing Countries')
plt.xlabel('GDP')
# Out:
# Text(0.5, 0, 'GDP')

# %% [markdown]
# FACTORS AFFECTING LIFE EXPECTANCY

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=df,x='Status',y='Life expectancy ')
plt.title('Average Life Expectancy by Country Status')
plt.xlabel('Country Status')
# Out:
# Text(0.5, 0, 'Country Status')

# %% [markdown]
# KEY FACTORS OVER TIME USING GDP,SCHOOLING AND IMMUNISATION

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=df,x='year',y='GDP',hue='Status')
plt.title('GDP Over Time for Developed and Developing Countries')
plt.xlabel('Year')
plt.ylabel('GDP')
# Out:
# Text(0, 0.5, 'GDP')

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=df,x='year',y='Schooling',hue='Status')
plt.title('Schooling Over Time for Developed and Developing Countries')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=df,x='year',y='infant deaths',hue='Status')
plt.title('Infant Deaths Over Time for Developed and Developing Countries')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# ased on the data and visualizations, we can summarize the factors affecting life expectancy:
#
# GDP: Higher GDP is typically associated with higher life expectancy. This trend is more pronounced in developed countries due to better healthcare infrastructure and economic stability.
#
# Schooling: Higher education levels correlate with higher life expectancy, reflecting better health awareness and access to healthcare services. The impact is significant in both developed and developing countries.
#
# Immunization: Higher immunization rates are crucial in developing countries, where preventable diseases significantly impact life expectancy. Developed countries generally have higher and more consistent immunization rates.
#
# Conclusion
# By contrasting these factors in developed and developing countries over time, we can identify that economic factors like GDP are significant in both, while improvements in health infrastructure (such as immunization) have a more immediate impact in developing countries.
