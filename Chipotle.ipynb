# %% [markdown]
# <a href="https://colab.research.google.com/github/RichardKameri/tydata/blob/main/Chipotle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Replace 'your_github_link_here' with the actual URL of the GitHub repository
# !git clone https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv
# Out:
# Cloning into 'chipotle.tsv'...
# remote: 404: Not Found
# fatal: repository 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv/' not found

# %%
chipo = pd.read_csv('/content/chipotle_usa_nutritions.csv')

# %%
# see the first 10 entries
chipo.head(10)
# Out:
#   Menu Type Menu Category                 Menu Item Size Type  \
# 0     Adult       Burrito                  Tortilla   Regular
# 1     Adult          Taco                  Tortilla   Regular
# 2     Adult      Toppings      Crispy Corn Tortilla   Regular
# 3     Adult          Rice  Cilantro-Lime Brown Rice   Regular
# 4     Adult          Rice  Cilantro-Lime White Rice   Regular
# 5     Adult         Beans               Black Beans   Regular
# 6     Adult         Beans               Pinto Beans   Regular
# 7     Adult       Veggies         Fajita Vegetables   Regular
# 8     Adult       Protein                  Barbacoa   Regular
# 9     Adult       Protein                   Chicken   Regular
#
#   Per Serving Size  Total Calories (cal)  Total Fat Calories (cal)  \
# 0             1 ea                   320                        80
# 1             1 ea                    80                        25
# 2             1 ea                    70                        25
# ...

# %%
# number of observations in the dataset
chipo.shape[0]
# Out:
# 102

# %%
# number of columns in the dataset
chipo.shape[1]
# Out:
# 17

# %%
# print all the columns
chipo.columns
# Out:
# Index(['Menu Type', 'Menu Category', 'Menu Item', 'Size Type',
#        'Per Serving Size', 'Total Calories (cal)', 'Total Fat Calories (cal)',
#        'Total Fats (g)', 'Saturated Fats (g)', 'Non-Saturated Fats (g)',
#        'Trans Fats (g)', 'Cholesterol (mg)', 'Sodium (g)', 'Carbohydrates (g)',
#        'Dietary Fiber (g)', 'Sugar (g)', 'Protein (g)'],
#       dtype='object')

# %%
# how is the dataset indexed
chipo.index
# Out:
# RangeIndex(start=0, stop=102, step=1)

# %%
# how many items were ordered in total
chipo['Per Serving Size'].sum()
# Out:
# '1 ea1 ea1 ea4 oz4 oz4 oz4 oz2.5 oz4 oz4 oz4 oz4 oz4 oz3.5 oz3.5 oz2 fl oz2 fl oz1 oz2 oz4 oz8 oz2 oz4 oz8 oz2.5 oz1 oz4 oz6 oz2 fl oz22 fl oz32 fl oz22 fl oz32 fl oz22 fl oz32 fl oz22 fl oz32 fl oz22 fl oz32 fl oz22 fl oz32 fl oz22 fl oz32 fl oz22 fl oz32 fl oz22 fl oz32 fl oz22 fl oz32 fl oz22 fl oz32 fl oz22 fl oz32 fl oz22 fl oz32 fl oz22 fl oz32 fl oz22 fl oz32 fl oz22 fl oz32 fl oz22 fl oz32 fl oz22 fl oz32 fl oz22 fl oz32 fl oz22 fl oz32 fl oz22 fl oz32 fl oz2 ea1 ea2 ea2 oz2 oz3 oz3 oz0.8 oz0.5 oz2 oz0.5 oz2 oz0.5 oz2 oz0.5 oz2 oz0.5 oz2 oz2 oz2 oz2 fl oz2 fl oz1 oz1 oz2 oz2 oz1 oz1 ea1 ea1 ea1 oz'
